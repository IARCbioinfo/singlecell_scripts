# %% [markdown]
# ## Dimensionality Reduction

# %%
import scanpy as sc
import numpy as np

sc.settings.verbosity = 0
sc.settings.set_figure_params(
    dpi=80,
    facecolor="white",
    frameon=False,
)

# %%
import os

os.environ['PYTHONHASHSEED'] = '0'

# %%
def dim_reduc(adata):
    
    np.random.seed(0)
    
    adata.X = adata.layers["log1p_norm"]
    
    sc.pp.neighbors(adata)
    sc.tl.umap(adata)
    
    sc.pl.umap(
    adata,
    color=["total_counts", "pct_counts_mt", "scDblFinder_score", "scDblFinder_class"],
    )
    
    return adata

# %%
adata3B = sc.read(
    filename="sample_3B/sample3B_feature_selection.h5ad")
# Out:
# /home/mangel/miniconda3/envs/meso2_conda_env/lib/python3.12/site-packages/anndata/__init__.py:55: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(

# %%
adata3B
# Out:
# AnnData object with n_obs × n_vars = 8933 × 17710
#     obs: 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'outlier', 'mt_outlier', 'is_outlier', 'sample', 'scDblFinder_score', 'scDblFinder_class'
#     var: 'gene_ids', 'feature_types', 'genome', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'highly_deviant', 'binomial_deviance', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg'
#     layers: 'counts', 'log1p_norm', 'soupX_counts'

# %%
adata26 = sc.read(
    filename="sample_26/sample26_feature_selection.h5ad")
# Out:
# /home/mangel/miniconda3/envs/meso2_conda_env/lib/python3.12/site-packages/anndata/__init__.py:55: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(

# %%
adata27 = sc.read(
    filename="sample_27/sample27_feature_selection.h5ad")
# Out:
# /home/mangel/miniconda3/envs/meso2_conda_env/lib/python3.12/site-packages/anndata/__init__.py:55: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(

# %%
adata35 = sc.read(
    filename="sample_35/sample35_feature_selection.h5ad")
# Out:
# /home/mangel/miniconda3/envs/meso2_conda_env/lib/python3.12/site-packages/anndata/__init__.py:55: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(

# %%
adata36 = sc.read(
    filename="sample_36/sample36_feature_selection.h5ad")
# Out:
# /home/mangel/miniconda3/envs/meso2_conda_env/lib/python3.12/site-packages/anndata/__init__.py:55: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(

# %%
adataTICP32 = sc.read(
    filename="sample_TICP32/sampleTICP32_feature_selection.h5ad")
# Out:
# /home/mangel/miniconda3/envs/meso2_conda_env/lib/python3.12/site-packages/anndata/__init__.py:55: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(

# %%
adata3B = dim_reduc(adata3B)
# Out:
# /home/mangel/miniconda3/envs/meso2_conda_env/lib/python3.12/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# /home/mangel/miniconda3/envs/meso2_conda_env/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata3B
# Out:
# AnnData object with n_obs × n_vars = 8933 × 17710
#     obs: 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'outlier', 'mt_outlier', 'is_outlier', 'sample', 'scDblFinder_score', 'scDblFinder_class'
#     var: 'gene_ids', 'feature_types', 'genome', 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'highly_deviant', 'binomial_deviance', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg', 'neighbors', 'umap', 'scDblFinder_class_colors'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'counts', 'log1p_norm', 'soupX_counts'
#     obsp: 'distances', 'connectivities'

# %%
adata26 = dim_reduc(adata26)
# Out:
# /home/mangel/miniconda3/envs/meso2_conda_env/lib/python3.12/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# /home/mangel/miniconda3/envs/meso2_conda_env/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata27 = dim_reduc(adata27)
# Out:
# /home/mangel/miniconda3/envs/meso2_conda_env/lib/python3.12/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# /home/mangel/miniconda3/envs/meso2_conda_env/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata35 = dim_reduc(adata35)
# Out:
# /home/mangel/miniconda3/envs/meso2_conda_env/lib/python3.12/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# /home/mangel/miniconda3/envs/meso2_conda_env/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata36 = dim_reduc(adata36)
# Out:
# /home/mangel/miniconda3/envs/meso2_conda_env/lib/python3.12/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# /home/mangel/miniconda3/envs/meso2_conda_env/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adataTICP32 = dim_reduc(adataTICP32)
# Out:
# /home/mangel/miniconda3/envs/meso2_conda_env/lib/python3.12/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# /home/mangel/miniconda3/envs/meso2_conda_env/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata3B.write("sample_3B/sample3B_dimensionality_reduction.h5ad")

# %%
adata26.write("sample_26/sample26_dimensionality_reduction.h5ad")

# %%
adata27.write("sample_27/sample27_dimensionality_reduction.h5ad")

# %%
adata35.write("sample_35/sample35_dimensionality_reduction.h5ad")

# %%
adata36.write("sample_36/sample36_dimensionality_reduction.h5ad")

# %%
adataTICP32.write("sample_TICP32/sampleTICP32_dimensionality_reduction.h5ad")
